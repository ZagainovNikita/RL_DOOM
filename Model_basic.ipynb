# %%
from vizdoom import *
import time
import random
import numpy as np
import gym
from gym import Env
from gym.spaces import Box, Discrete
import cv2
import matplotlib.pyplot as plt
import torch
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
game = DoomGame()
game.load_config("github/VizDoom/scenarios/basic.cfg")
game.init()

# %%
actions = np.identity(3, dtype=np.uint8)

# %%
# Loop through episodes 
episodes = 1
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),1)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(1)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# reward: -1.0
# reward: -1.0
# reward: -1.0
# reward: -1.0
# reward: -1.0
# reward: 100.0
# reward: -1.0
# Result: 94.0

# %%
game.close()

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('github/VizDoom/scenarios/basic.cfg')
        
        # Render frame logic
        if render == False: 
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=False)

# %%
plt.imshow(env.reset(), cmap="gray")
env.close()

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

callback = TrainAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %%
env = VizDoomGym()
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# D:\Python\Python312\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.6     |
# |    ep_rew_mean     | -72.5    |
# | time/              |          |
# |    fps             | 128      |
# |    iterations      | 1        |
# |    time_elapsed    | 15       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.5         |
# |    ep_rew_mean          | -51.7        |
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 2            |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068847965 |
# |    clip_fraction        | 0.12         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -5.53e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 925          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000526    |
# |    value_loss           | 2.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.2        |
# |    ep_rew_mean          | -75.5       |
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 3           |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011618282 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 3.66e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.9        |
# |    ep_rew_mean          | -78.1       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 4           |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013901817 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00247     |
# |    value_loss           | 2.89e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | -67.1       |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 5           |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010726025 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00167     |
# |    value_loss           | 3.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -16.7       |
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 6           |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011267255 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00358     |
# |    value_loss           | 4.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.3        |
# |    ep_rew_mean          | -34.6       |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 7           |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020256525 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.38e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000659   |
# |    value_loss           | 4.47e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | -43.2       |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 8           |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.013200944 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00123     |
# |    value_loss           | 3.62e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20.8       |
# |    ep_rew_mean          | -15.2      |
# | time/                   |            |
# |    fps                  | 83         |
# |    iterations           | 9          |
# |    time_elapsed         | 220        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.04480876 |
# |    clip_fraction        | 0.347      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.955     |
# |    explained_variance   | 0.507      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.53e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0126     |
# |    value_loss           | 3.63e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | -24.1       |
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 10          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018221444 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.42e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.00449     |
# |    value_loss           | 3.21e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.8         |
# |    ep_rew_mean          | -22.9        |
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 11           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0084657185 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.761       |
# |    explained_variance   | 0.574        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.75e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00815      |
# |    value_loss           | 3.16e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16         |
# |    ep_rew_mean          | 9.82       |
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 12         |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01887744 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.818     |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.28e+03   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.00813    |
# |    value_loss           | 1.88e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.3        |
# |    ep_rew_mean          | -24.2       |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 13          |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019126942 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00611     |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | 12.2        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 14          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.022143565 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.799      |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.05e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00607     |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.4        |
# |    ep_rew_mean          | 42.4        |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 15          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.025147451 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.97e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.5        |
# |    ep_rew_mean          | 39.6        |
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 16          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023963505 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.8e+03     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00362     |
# |    value_loss           | 3.75e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.2        |
# |    ep_rew_mean          | 37.7        |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 17          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.028059741 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.789      |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.54e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.018       |
# |    value_loss           | 2.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.53        |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 18          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022732854 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1e+03       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000895   |
# |    value_loss           | 2.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.86        |
# |    ep_rew_mean          | 70.4        |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 19          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.029271599 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.829      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 954         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00969     |
# |    value_loss           | 1.74e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.45       |
# |    ep_rew_mean          | 67.8       |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 20         |
# |    time_elapsed         | 433        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03998415 |
# |    clip_fraction        | 0.319      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.772     |
# |    explained_variance   | 0.837      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 316        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0179     |
# |    value_loss           | 1.5e+03    |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.84     |
# |    ep_rew_mean          | 75.6     |
# | time/                   |          |
# |    fps                  | 80       |
# |    iterations           | 21       |
# |    time_elapsed         | 536      |
# |    total_timesteps      | 43008    |
# | train/                  |          |
# |    approx_kl            | 0.075132 |
# |    clip_fraction        | 0.341    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.705   |
# |    explained_variance   | 0.738    |
# |    learning_rate        | 0.0001   |
# |    loss                 | 522      |
# |    n_updates            | 200      |
# |    policy_gradient_loss | 0.00159  |
# |    value_loss           | 850      |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.42        |
# |    ep_rew_mean          | 77.8        |
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 22          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.051911063 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 272         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0259      |
# |    value_loss           | 514         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.48        |
# |    ep_rew_mean          | 77.3        |
# | time/                   |             |
# |    fps                  | 67          |
# |    iterations           | 23          |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.029194351 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.479      |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 243         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00699     |
# |    value_loss           | 329         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5         |
# |    ep_rew_mean          | 80.2      |
# | time/                   |           |
# |    fps                  | 64        |
# |    iterations           | 24        |
# |    time_elapsed         | 761       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0511984 |
# |    clip_fraction        | 0.269     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.48     |
# |    explained_variance   | 0.61      |
# |    learning_rate        | 0.0001    |
# |    loss                 | 265       |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0137   |
# |    value_loss           | 522       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.57        |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 25          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.036507156 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.486      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 55.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0363      |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.44        |
# |    ep_rew_mean          | 79.4        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 26          |
# |    time_elapsed         | 926         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.021756817 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 74.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00387     |
# |    value_loss           | 160         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.43        |
# |    ep_rew_mean          | 84.6        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 27          |
# |    time_elapsed         | 953         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.016472973 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.349      |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 55.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.02        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 28          |
# |    time_elapsed         | 972         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.035957664 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0367      |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.55        |
# |    ep_rew_mean          | 83.9        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 29          |
# |    time_elapsed         | 1000        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.017875649 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 19.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00469     |
# |    value_loss           | 63.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.08       |
# |    ep_rew_mean          | 86.3       |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 30         |
# |    time_elapsed         | 1035       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03238973 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.207     |
# |    explained_variance   | 0.568      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 47.4       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | 0.0222     |
# |    value_loss           | 137        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.4         |
# |    ep_rew_mean          | 85          |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 31          |
# |    time_elapsed         | 1163        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.027285436 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.236      |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 37.6        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0277      |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.38        |
# |    ep_rew_mean          | 84.8        |
# | time/                   |             |
# |    fps                  | 54          |
# |    iterations           | 32          |
# |    time_elapsed         | 1194        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.038204495 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0235      |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.43        |
# |    ep_rew_mean          | 84.2        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 33          |
# |    time_elapsed         | 1212        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019966355 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.164      |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.8        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00568     |
# |    value_loss           | 42.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.94        |
# |    ep_rew_mean          | 86.5        |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 34          |
# |    time_elapsed         | 1229        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.031168513 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.147      |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 70.3        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0116      |
# |    value_loss           | 87.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.35        |
# |    ep_rew_mean          | 84.8        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 35          |
# |    time_elapsed         | 1248        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013809978 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.124      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15          |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00412     |
# |    value_loss           | 39.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.31       |
# |    ep_rew_mean          | 85.2       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 36         |
# |    time_elapsed         | 1265       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.10202986 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.127     |
# |    explained_variance   | 0.58       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 14.2       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00169   |
# |    value_loss           | 91.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.09       |
# |    ep_rew_mean          | 86.4       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 37         |
# |    time_elapsed         | 1295       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.04900931 |
# |    clip_fraction        | 0.0979     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.125     |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 12.7       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.0111     |
# |    value_loss           | 50         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.85        |
# |    ep_rew_mean          | 87.5        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 38          |
# |    time_elapsed         | 1330        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.013552889 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.8        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00919     |
# |    value_loss           | 55.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.44        |
# |    ep_rew_mean          | 84.7        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 39          |
# |    time_elapsed         | 1350        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.028343972 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.139      |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.6         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0134      |
# |    value_loss           | 29.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.57        |
# |    ep_rew_mean          | 88.5        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 40          |
# |    time_elapsed         | 1370        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012927202 |
# |    clip_fraction        | 0.0573      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.34        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00926     |
# |    value_loss           | 28.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.97        |
# |    ep_rew_mean          | 86.9        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 41          |
# |    time_elapsed         | 1391        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.013813045 |
# |    clip_fraction        | 0.0663      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.128      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.9        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00961     |
# |    value_loss           | 34.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.44         |
# |    ep_rew_mean          | 85           |
# | time/                   |              |
# |    fps                  | 60           |
# |    iterations           | 42           |
# |    time_elapsed         | 1411         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0079885265 |
# |    clip_fraction        | 0.0543       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.112       |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.19         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.0296       |
# |    value_loss           | 12.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4           |
# |    ep_rew_mean          | 86.9        |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 43          |
# |    time_elapsed         | 1431        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005186598 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 26.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00932     |
# |    value_loss           | 41.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.03        |
# |    ep_rew_mean          | 86.4        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 44          |
# |    time_elapsed         | 1451        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.017295547 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0965     |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.73        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00913     |
# |    value_loss           | 20.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.04       |
# |    ep_rew_mean          | 86.1       |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 45         |
# |    time_elapsed         | 1475       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.03502616 |
# |    clip_fraction        | 0.0485     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0906    |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 9.92       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.0115     |
# |    value_loss           | 21.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.8         |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 46          |
# |    time_elapsed         | 1496        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030276401 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0715     |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0042      |
# |    value_loss           | 34          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13        |
# |    ep_rew_mean          | 85.9        |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 47          |
# |    time_elapsed         | 1516        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.058245473 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0734     |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.82        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0049      |
# |    value_loss           | 27.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.07        |
# |    ep_rew_mean          | 86.1        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 48          |
# |    time_elapsed         | 1532        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.026586346 |
# |    clip_fraction        | 0.0499      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.081      |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.6        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00958     |
# |    value_loss           | 19.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.72        |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 64          |
# |    iterations           | 49          |
# |    time_elapsed         | 1549        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.023225404 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0734     |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 32.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00425     |
# |    value_loss           | 45.7        |
# -----------------------------------------

# %%
trained_model = PPO.load("./train/train_basic/best_model_100000.zip")

# %%
env = VizDoomGym(render=True)

for episode in range(10):
    state = env.reset()
    done = False
    while not done:
        pred = trained_model.predict(state)
        state, _, done, _ = env.step(pred[0])
        time.sleep(1/20)
    time.sleep(2)
env.close()
